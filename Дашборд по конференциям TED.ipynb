# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера 2</b></font>
#
# Привет еще раз. Спасибо, что доделала работу. Улучшения увидел. На последней странице имел в виду столбчатую диаграмму с ращбивкой по темам и году. Так мы сможем детально по темам сравнить их динамику за последние годы. В остальном все хорошо. Поздравляю со сданным проектом. Надеюсь, он был интересен и познавателен. Успехов в дальнейшем пути :)
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Привет, Екатерина! Спасибо, что прислала задание:) Меня зовут Слепцов Артем и я буду проверять твой проект) Извиини за задержку при проверке. Ты проделала большую работу над проектом. Он выполнен уже на достойном уровне. Однако есть моменты, которые еще можно улучшить. Будет здорово, если ты, надеюсь, не против, если я буду на ты, будешь отвечать на комментарии и участвовать в диалоге. Если обращение на ты неприемлемо, то прошу сообщить.
#
# Мои комментарии обозначены пометкой **Комментарий ревьюера**. Далее в файле ты сможешь найти их в похожих ячейках:
#
# <div class="alert alert-success">Успех: Если фон комментария зелёный - всё сделано правильно. Рекомендации укажу таким же цветом;</div>
#
# <div class="alert alert-warning">Совет: Оранжевый - некритичные замечания;</div>
#
# <div class="alert alert-danger">Ошибка: Красный - нужно переделать. </div>
#
# Не удаляй эти комментарии и постарайся учесть их в ходе выполнения данного проекта. Свои же комментарии ты можешь обозначать любым заметным способом.
#
# </div>

# %% [markdown]
# Обновленная презентация в Tableau: <https://public.tableau.com/views/_16867413511020/sheet20?:language=en-US&:display_count=n&:origin=viz_share_link>

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Успех: Графики на первой странице сделаны корректно, молодец. Диапазон рассматриваемых лет также выбран верно. Здорово, что ты не забыла добавить и фильтр по периоду. С приведенными комментариями согласен. Рекомендую лишь подумать над тем, почему в последние годы наблюдается спад по темам науки и культуры. Также можно добавить сет с выбором числа тем при отображении на 2 и 3 графике.
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Успех: Вторая страница. Опять же графики сделаны правильно. Это очень здорово. По данному дашборду приведу рекомендации. На круговой диаграмме лучше добавить проценты. Все же данный тип графика используется для отображения долей. Далее в таблице по странам также можно добавить категорию "Другие" для понимания общей ситуации. Приведенные комментарии сделаны очень подробно 👍 Единственный момент, лучше все же разделить подачу информации. Сделать сначала графики, а затем уже привести комментарии по ним в нижней части дашборда.
#
# </div>

# %% [markdown]
# **Добавила проценты на круговой диаграмме. Добавила категорию "Другие" в таблице.**

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Успех: Функционал третьей страницы дашборда реализован снова правильно. Прекрасная работа, молодец. Таблицы выводят нужный результат при выделении соответствующей темы. Сет также построен правильно 👍
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Успех: Последняя страница также построена. С ней рекомендую поработать детальнее. Лучше на первом графике ввывести число выступлений в каждой категории в зависимости от года. Сделать это лучше столбчатой диаграммой. Так мы детальнее сравним 3 года, не приидется изучать круговые диаграммы каждого года. В целом, не рекомендую использовать пироговые диаграммы (pie-charts). Такая диаграмма затрудняет понимание, особенно если сегментов будет больше 4х. Также, на этом типе диаграмм сложно визуально увидеть разницу между сегментами. лучше использовать обычные столбчатые диаграммы вместо пироговых диаграмм.
#
#
# </div>

# %% [markdown]
# **Добавила дополнительный лист со столбчатой диаграммой :)**

# %% [markdown]
# <div class="alert alert-info">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Рекомендую посмотреть возможности Tableau в данной подборке - https://public.tableau.com/app/discover/viz-of-the-day. Также привожу ссылку на некоторые полезные правила [оформления](https://ux.pub/10-pravil-proektirovaniya-paneli-dashbordov/) дашбордов.
#
# Ты проделала большую работу, молодец! У тебя получился очень крутой проект) Привел рекомендации, которые можно учесть в данном проекте. При возникновении вопросов обязательно их задавай. Но т.к. критичных моментов нет, то твой проект я могу принять и в таком виде. Если нет времени на улучшения, то просто верни проект мне обратно. Жду твою работу :)
#
# </div>
